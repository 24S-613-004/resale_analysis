# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from datetime import datetime as dt
# import datetime as dt
from scheduler import Scheduler
import scheduler.trigger as trigger

# %% [markdown]
# # Doen Dresses

# %% [markdown]
# ## Extract

# %%
# Sold Doen Dresses
url = 'https://poshmark.com/search?query=Doen&brand%5B%5D=Doen&availability=sold_out&department=Women&category=Dresses'
brand = 'doen'
category = 'dress'

response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Set dress styles

# %%
# Dresses
dresses = [
    "Ischia", "Marianne", "Rosaria", "Lisbeth", "Wilmina",
    "Aurora", "Delphine", "Clara", "Sabine", "Odette",
    "Evelyn", "Juliette", "Amelie", "Camille", "Vera",
    "Fiona", "Nina", "Corinne", "Helene", "Lucille",
    "Margot", "Anya", "Freya", "Sylvie", "Celine",
    "Daphne", "Iris", "Luna", "Flora", "Amara",
    "Maeve", "Adelaide", "Ophelia", "Scarlett", "Viola",
    "Anastasia", "Claudia", "Elise", "Matilda", "Eloise",
    "Gwendolyn", "Ivy", "Cecilia", "Esme", "Tessa",
    "Madeleine", "Poppy", "Adele", "Serena", "Genevieve",
    "Lorraine", "Merla", "Narcisse", "Augustina", "Sabrina",
    "Alessandra", "Leyah", "Guinevere", "Francetta", "Kaira",
    "Raquella", "Pamelina", "Quinn", "Celestine", "Emmaretta",
    "Piper", "Violetta", "Noisette", "Franique", "Sera",
    "Lovisa", "Rhodia", "Gladys"
]


dresses = [x.lower() for x in dresses]
dresses = [x +' ' for x in dresses] # add a space after the name to exlude partial matches

# %% [markdown]
# ### Create Dataframe

# %%
titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    for dress in dresses:
        if dress in title:
            style = dress
            break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"dress",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/4273441335.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)

# %%
df.head()
# Out:
#                                                title  price size category  \
# 0                               doen celestine dress  250.0    M    dress
# 1  doen victorie maxi dress in mirbeau garden flo...  200.0    M    dress
# 2  doen brooke dress harvest meadow floral maxi d...  140.0   XL    dress
# 3          doen poet ruffled midi dress - black - xs  160.0   XS    dress
# 4      doen carina eyelet mini dress black - size xl  150.0   XL    dress
#
#         style brand
# 0  celestine   doen
# 1        None  doen
# 2        None  doen
# 3        None  doen
# 4        None  doen

# %% [markdown]
# ## Load

# %%
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
#                                                title  price size category  \
# 0                               doen celestine dress  250.0    M    dress
# 1  doen victorie maxi dress in mirbeau garden flo...  200.0    M    dress
# 2  doen brooke dress harvest meadow floral maxi d...  140.0   XL    dress
# 3          doen poet ruffled midi dress - black - xs  160.0   XS    dress
# 4      doen carina eyelet mini dress black - size xl  150.0   XL    dress
#
#         style brand      ingest_timestamp
# 0  celestine   doen  2024-Dec-29-22:43:03
# 1        None  doen  2024-Dec-29-22:43:03
# 2        None  doen  2024-Dec-29-22:43:03
# 3        None  doen  2024-Dec-29-22:43:03
# 4        None  doen  2024-Dec-29-22:43:03

# %% [markdown]
# # Doen Tops

# %% [markdown]
# ## Extract

# %%
# Sold Doen Tops
url = 'https://poshmark.com/brand/Doen-Women-Tops?availability=sold_out'
brand = 'doen'
category = 'top'

response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Set Styles

# %%
# Tops
tops = [
    "Henri", "Anisa", "Emiliana", "Ingrid", "Joelle",
    "Celeste", "Faye", "Gabrielle", "Juliana", "Odessa",
    "Viola", "Monique", "Sophie", "Claudine", "Elena",
    "Leona", "Paloma", "Bianca", "Marisol", "Estelle",
    "Inez", "Lorena", "Delilah", "Jocelyn", "Amara",
    "Colette", "Marielle", "Florelle", "Adeline", "Renee",
    "Sabrina", "Fleur", "Noemi", "Simone", "Vera",
    "Natalia", "Yvette", "Clarisse", "Odile", "Beatrice",
    "Camilla", "Tatiana", "Nadia", "Cleo", "Lydia",
    "Josephine", "Evelina", "Lucia", "Freya", "Marion",
    "Scarlet", "Jane", "June", "Lille", "Fidella", "Frederica",
    "Anaya", "Idella", "Baptisia", "Eldoris", "Camri",
    "Jacey", "Leia", "Amaline", "Solange", "Evette",
    "Lois", "Alida", "Ashby", "Nerida", "Agotha",
    "Frances", "Paola", "Vivienne"
]

tops = [x.lower() for x in tops]
tops = [x +' ' for x in tops] # add a space after the name to exlude partial matches

# %% [markdown]
# ### Create Dataframe

# %%
titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    for top in tops:
        if top in title:
            style = top
            break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"top",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/2740038286.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)

# %% [markdown]
# ## Load

# %%
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')
   
df.head()
# Out:
#                                                title  price size category  \
# 0            doen black albertine blouse top size xl  130.0   XL      top
# 1                           doen vera top in salt xs  125.0   XS      top
# 2                  dòen flowered blouse of good size   90.0    L      top
# 3       doen narcissa top in pink valley floral pink  110.0   XS      top
# 4  doen viola black and white floral ruffled top ...   90.0    L      top
#
#     style brand      ingest_timestamp
# 0    None  doen  2024-Dec-29-22:43:05
# 1   vera   doen  2024-Dec-29-22:43:05
# 2    None  doen  2024-Dec-29-22:43:05
# 3    None  doen  2024-Dec-29-22:43:05
# 4  viola   doen  2024-Dec-29-22:43:05

# %% [markdown]
# # Doen Skirts

# %% [markdown]
# ## Extract

# %%
# Sold Doen Skirts
url = 'https://poshmark.com/brand/Doen-Women-Skirts?availability=sold_out'
brand = 'doen'
category = 'skirt'

response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Set Styles

# %%
# Skirts
skirts = [
    "Elowen", "Sebastiane", "Raina", "Beatrice", "Florence",
    "Odile", "Esther", "Giselle", "Clementine", "Simone",
    "Aurora", "Emmeline", "Coralie", "Juliet", "Isadora",
    "Felicity", "Lucia", "Vivienne", "Celestine", "Anais",
    "Noelle", "Gabriella", "Liliana", "Violette", "Rosalind",
    "Allegra", "Seraphina", "Eleanor", "Arden", "Madeleine",
    "Sophia", "Helena", "Marguerite", "Arabelle", "Isla",
    "Delphine", "Anouk", "Carys", "Evangeline", "Maris",
    "Odessa", "Viola", "Lenore", "Selene", "Camille",
    "Amelie", "Liora", "Fiona", "Adria", "Melisande","Elowena",
    "Nandi","Cheri","Fabienne","Rieti","Sanremo"
]

skirts = [x.lower() for x in skirts]
# skirts = [x +' ' for x in skirts] # add a space after the name to exlude partial matches

# %% [markdown]
# ### Create Dataframe

# %%
titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    for skirt in skirts:
        if skirt in title:
            style = skirt
            break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/4117187307.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)

# %% [markdown]
# ## Load

# %%
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')
   
df.head()
# Out:
#                                                title  price     size category  \
# 0  doen elowena skirt in villette paisley, brand ...  170.0        S    skirt
# 1  doen sebastiane lace skirt in black, brand new...  180.0        S    skirt
# 2                doen nandi skirt in daffodil yellow  168.0  Various    skirt
# 3  doen sebastiane lace skirt in black, brand new...  180.0       XS    skirt
# 4            nwt doen elowen skirt in deep navy sz m  220.0        M    skirt
#
#         style brand      ingest_timestamp
# 0      elowen  doen  2024-Dec-29-22:43:07
# 1  sebastiane  doen  2024-Dec-29-22:43:07
# 2       nandi  doen  2024-Dec-29-22:43:07
# 3  sebastiane  doen  2024-Dec-29-22:43:07
# 4      elowen  doen  2024-Dec-29-22:43:07

# %% [markdown]
# # Hill House

# %% [markdown]
# ## Dresses

# %%
# Sold Hil House Dresses
url = 'https://poshmark.com/brand/Hill_House-Women-Dresses?availability=sold_out'
brand = 'hill_house'
category = 'dress'


response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/2854757080.py:39: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0  new! hill house cosima nap dress chocolate ton...  345.0    L    skirt
# 1   new hill house ellie nap dress in navy gingham l   94.0    L    skirt
# 2  hill house home ellie nap dress midi powder bl...   35.0    L    skirt
# 3                         hill house ellie nap dress   65.0   XS    skirt
# 4      hill house - the ellie nap dress (ski chalet)   85.0  XXS    skirt
#
#   style       brand      ingest_timestamp
# 0  None  hill_house  2024-Dec-29-22:43:08
# 1  None  hill_house  2024-Dec-29-22:43:08
# 2  None  hill_house  2024-Dec-29-22:43:08
# 3  None  hill_house  2024-Dec-29-22:43:08
# 4  None  hill_house  2024-Dec-29-22:43:08

# %% [markdown]
# ## Skirts

# %%
url = 'https://poshmark.com/brand/Hill_House-Women-Skirts?availability=sold_out'
brand = 'hill_house'
category = 'skirt'


response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/2169770661.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0                               hill house skirt nwt   80.0    S    skirt
# 1               hill house size l delphine skirt nwt   25.0    L    skirt
# 2  hill house home nwt sz l delphine nap skirt na...   50.0    L    skirt
# 3                           hill house mirabel skirt   55.0    M    skirt
# 4   nwt hill house home paz linen mini skirt in navy   12.0    M    skirt
#
#   style       brand      ingest_timestamp
# 0  None  hill_house  2024-Dec-29-22:43:09
# 1  None  hill_house  2024-Dec-29-22:43:09
# 2  None  hill_house  2024-Dec-29-22:43:09
# 3  None  hill_house  2024-Dec-29-22:43:09
# 4  None  hill_house  2024-Dec-29-22:43:09

# %% [markdown]
# ## Tops

# %%
url = 'https://poshmark.com/brand/Hill_House-Women-Tops?availability=sold_out'
brand = 'hill_house'
category = 'top'


response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/985343237.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0          hill house home jewel jammie top in white   37.0    S    skirt
# 1       hill house kit top in white, size s like new   22.0    S    skirt
# 2           nwt hill house home gingham collared top   18.0    S    skirt
# 3  hill house home aiko nap top in emerald botani...   16.0   XS    skirt
# 4             hill house home kit top - size: medium   40.0    M    skirt
#
#   style       brand      ingest_timestamp
# 0  None  hill_house  2024-Dec-29-22:43:11
# 1  None  hill_house  2024-Dec-29-22:43:11
# 2  None  hill_house  2024-Dec-29-22:43:11
# 3  None  hill_house  2024-Dec-29-22:43:11
# 4  None  hill_house  2024-Dec-29-22:43:11

# %% [markdown]
# # Agua by Agua Bendita

# %% [markdown]
# ## Dresses

# %%
url = 'https://poshmark.com/brand/Agua_by_Agua_Bendita-Women-Dresses?availability=sold_out'
brand = 'aguaByAguaBendita'
category = 'dress'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/3420597893.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0      agua bendita mambo primavera linen midi dress  245.0    S    skirt
# 1  agua by agua bendita manzanilla anturios mini ...  145.0   XS    skirt
# 2  agua agua bendita sucre cut-out poplin floral ...   95.0    S    skirt
# 3  agua by agua bendita caramelo primavera cotton...   15.0    S    skirt
# 4        nwot agua by agua bendita floral midi dress   80.0    M    skirt
#
#   style              brand      ingest_timestamp
# 0  None  aguaByAguaBendita  2024-Dec-29-22:43:12
# 1  None  aguaByAguaBendita  2024-Dec-29-22:43:12
# 2  None  aguaByAguaBendita  2024-Dec-29-22:43:12
# 3  None  aguaByAguaBendita  2024-Dec-29-22:43:12
# 4  None  aguaByAguaBendita  2024-Dec-29-22:43:12

# %% [markdown]
# ## Skirts

# %%
url = 'https://poshmark.com/brand/Agua_by_Agua_Bendita-Women-Skirts?availability=sold_out'
brand = 'aguaByAguaBendita'
category = 'skirt'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/4087335670.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title   price  \
# 0  agua by agua bendita lavanda cotton silk blend...   220.0
# 1    agua by agua bendita arroyo caracola midi skirt  2100.0
# 2  agua by agua bendita 'bergamota' green printed...   250.0
# 3  agua bendita astro esmeralda lavanda sarong pa...   110.0
# 4  agua by agua bendita\nalcachofa printed cotton...   147.0
#
#                   size category style              brand      ingest_timestamp
# 0  one size fits S-M-L    skirt  None  aguaByAguaBendita  2024-Dec-29-22:43:14
# 1                    S    skirt  None  aguaByAguaBendita  2024-Dec-29-22:43:14
# 2                    S    skirt  None  aguaByAguaBendita  2024-Dec-29-22:43:14
# 3             One Size    skirt  None  aguaByAguaBendita  2024-Dec-29-22:43:14
# 4                    M    skirt  None  aguaByAguaBendita  2024-Dec-29-22:43:14

# %% [markdown]
# ## Tops

# %%
url = 'https://poshmark.com/brand/Reformation-Women-Tops?availability=sold_out'
brand = 'aguaByAguaBendita'
category = 'top'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/3041756085.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0  reformation women will oversize shirt long sle...   48.0    M    skirt
# 1                                    reformation top   34.0   XS    skirt
# 2                                   🌹reformation top   35.0    2    skirt
# 3  reformation women hearth long sleeve top peat ...   50.0   12    skirt
# 4  reformation novena white ruffle tie strap tank...   30.0    2    skirt
#
#   style              brand      ingest_timestamp
# 0  None  aguaByAguaBendita  2024-Dec-29-22:43:16
# 1  None  aguaByAguaBendita  2024-Dec-29-22:43:16
# 2  None  aguaByAguaBendita  2024-Dec-29-22:43:16
# 3  None  aguaByAguaBendita  2024-Dec-29-22:43:16
# 4  None  aguaByAguaBendita  2024-Dec-29-22:43:16

# %% [markdown]
# # Reformation

# %% [markdown]
# ## Dresses

# %%
url = 'https://poshmark.com/brand/Reformation-Women-Dresses?availability=sold_out'
brand = 'reformation'
category = 'dress'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/2906826115.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0  reformation pia velvet dress crystal embellish...  150.0    2    skirt
# 1  ✨ reformation jagger square neck minidress in ...   38.0    M    skirt
# 2  reformation black knit maxi dress long sleeves...   14.0   XL    skirt
# 3  reformation cello long sleeve midi dress 1x gr...  115.0   1X    skirt
# 4  reformation jeans linah mini fit and flare dre...  115.0    M    skirt
#
#   style        brand      ingest_timestamp
# 0  None  reformation  2024-Dec-29-22:43:17
# 1  None  reformation  2024-Dec-29-22:43:17
# 2  None  reformation  2024-Dec-29-22:43:17
# 3  None  reformation  2024-Dec-29-22:43:17
# 4  None  reformation  2024-Dec-29-22:43:17

# %% [markdown]
# ## Skirts

# %%
url = 'https://poshmark.com/brand/Reformation-Women-Skirts?availability=sold_out'
brand = 'reformation'
category = 'skirt'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/2791773511.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0  reformation bronze gold 100% silk twist front ...   27.0    2    skirt
# 1  reformation mini skirt. size 4. brand new. msr...   65.0    4    skirt
# 2                              reformation bea skirt   80.0    8    skirt
# 3                    reformation robbie skirt (army)   38.0    8    skirt
# 4                              reformation bea skirt   33.0    0    skirt
#
#   style        brand      ingest_timestamp
# 0  None  reformation  2024-Dec-29-22:43:19
# 1  None  reformation  2024-Dec-29-22:43:19
# 2  None  reformation  2024-Dec-29-22:43:19
# 3  None  reformation  2024-Dec-29-22:43:19
# 4  None  reformation  2024-Dec-29-22:43:19

# %% [markdown]
# ## Tops

# %%
url = 'https://poshmark.com/brand/Reformation-Women-Tops?availability=sold_out'
brand = 'reformation'
category = 'top'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/2993204323.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price size category  \
# 0  reformation women will oversize shirt long sle...   48.0    M    skirt
# 1                                    reformation top   34.0   XS    skirt
# 2                                   🌹reformation top   35.0    2    skirt
# 3  reformation women hearth long sleeve top peat ...   50.0   12    skirt
# 4  reformation novena white ruffle tie strap tank...   30.0    2    skirt
#
#   style        brand      ingest_timestamp
# 0  None  reformation  2024-Dec-29-22:43:21
# 1  None  reformation  2024-Dec-29-22:43:21
# 2  None  reformation  2024-Dec-29-22:43:21
# 3  None  reformation  2024-Dec-29-22:43:21
# 4  None  reformation  2024-Dec-29-22:43:21

# %% [markdown]
# # Zimmerman

# %% [markdown]
# ## Dresses

# %%
url = 'https://poshmark.com/brand/zimmerman-Women-Dresses?availability=sold_out'
brand = 'zimmerman'
category = 'dress'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/366463971.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price     size category  \
# 0                          zimmerman georgette dress  195.0        6    skirt
# 1                                          zimmerman  350.0        6    skirt
# 2  zimmerman off shoulder white 3/4 sleeves multi...   89.0  1 (4-6)    skirt
# 3  zimmerman ready to wear wonderland floral bias...  700.0        6    skirt
# 4  zimmermann melody off shoulder mini dress yell...  138.0        4    skirt
#
#   style      brand      ingest_timestamp
# 0  None  zimmerman  2024-Dec-29-22:43:22
# 1  None  zimmerman  2024-Dec-29-22:43:22
# 2  None  zimmerman  2024-Dec-29-22:43:22
# 3  None  zimmerman  2024-Dec-29-22:43:22
# 4  None  zimmerman  2024-Dec-29-22:43:22

# %% [markdown]
# ## Skirts

# %%
url = 'https://poshmark.com/brand/zimmerman-Women-Skirts?availability=sold_out'
brand = 'zimmerman'
category = 'skirt'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/1497543000.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                    title  price size category style      brand  \
# 0  black and white skirt   25.0    M    skirt  None  zimmerman
#
#        ingest_timestamp
# 0  2024-Dec-29-22:43:23

# %% [markdown]
# ## Tops

# %%
url = 'https://poshmark.com/brand/zimmerman-Women-Tops?availability=sold_out'
brand = 'zimmerman'
category = 'top'

response = requests.get(url)
# response.status_code

html = response.text
soup = BeautifulSoup(html, "html.parser") 

titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style','brand']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:].replace(",",""))
    size = sizes[x].text.strip()[6:]
    
    style = None
    # for skirt in skirts:
    #     if skirt in title:
    #         style = skirt
    #         break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style,
                 'brand':brand}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
    
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/{brand}_{category}_{file_timestamp}.csv',index=False)

# Log process
message = f"{brand} {category} Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

df.head()
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_1740/12789195.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)
#                                                title  price              size  \
# 0               #49 zimmermann lace off shoulder top   66.0                 6
# 1                 zimmerman - botanica wattle blouse  440.0                 6
# 2  zimmerman botanica high- neck cropped bow-tie ...  950.0   Size 4 or US 12
# 3    nwt zimmerman kali hibiscus linen blouse size 1   70.0                 S
# 4       zimmerman silk organza paisley print top sz3   50.0  Size 3 ZImmerman
#
#   category style      brand      ingest_timestamp
# 0    skirt  None  zimmerman  2024-Dec-29-22:43:24
# 1    skirt  None  zimmerman  2024-Dec-29-22:43:24
# 2    skirt  None  zimmerman  2024-Dec-29-22:43:24
# 3    skirt  None  zimmerman  2024-Dec-29-22:43:24
# 4    skirt  None  zimmerman  2024-Dec-29-22:43:24

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Product Style Names

# %%
# # Tops
# tops = [
#     "Henri", "Anisa", "Emiliana", "Ingrid", "Joelle",
#     "Celeste", "Faye", "Gabrielle", "Juliana", "Odessa",
#     "Viola", "Monique", "Sophie", "Claudine", "Elena",
#     "Leona", "Paloma", "Bianca", "Marisol", "Estelle",
#     "Inez", "Lorena", "Delilah", "Jocelyn", "Amara",
#     "Colette", "Marielle", "Florelle", "Adeline", "Renee",
#     "Sabrina", "Fleur", "Noemi", "Simone", "Vera",
#     "Natalia", "Yvette", "Clarisse", "Odile", "Beatrice",
#     "Camilla", "Tatiana", "Nadia", "Cleo", "Lydia",
#     "Josephine", "Evelina", "Lucia", "Freya", "Marion"
# ]

# # Skirts
# skirts = [
#     "Elowen", "Sebastiane", "Raina", "Beatrice", "Florence",
#     "Odile", "Esther", "Giselle", "Clementine", "Simone",
#     "Aurora", "Emmeline", "Coralie", "Juliet", "Isadora",
#     "Felicity", "Lucia", "Vivienne", "Celestine", "Anais",
#     "Noelle", "Gabriella", "Liliana", "Violette", "Rosalind",
#     "Allegra", "Seraphina", "Eleanor", "Arden", "Madeleine",
#     "Sophia", "Helena", "Marguerite", "Arabelle", "Isla",
#     "Delphine", "Anouk", "Carys", "Evangeline", "Maris",
#     "Odessa", "Viola", "Lenore", "Selene", "Camille",
#     "Amelie", "Liora", "Fiona", "Adria", "Melisande"
# ]

# # Pants
# pants = [
#     "Diana", "Clara", "Eloise", "Harper", "Amalia",
#     "Marguerite", "Florine", "Estelle", "Genevieve", "Sabine",
#     "Odessa", "Lorelei", "Miriam", "Joanna", "Lenore",
#     "Viviana", "Cecile", "Delia", "Lucinda", "Aurora",
#     "Francesca", "Eliana", "Isobel", "Norah", "Camille",
#     "Selena", "Veronica", "Marina", "Adela", "Corinne",
#     "Penelope", "Rosalyn", "Evelyn", "Jocasta", "Beatrice",
#     "Cressida", "Natalia", "Florence", "Sophia", "Lyra",
#     "Octavia", "Philippa", "Sabina", "Clarissa", "Giselle",
#     "Ines", "Amara", "Elara", "Lucille", "Mattea"
# ]

# # Jeans
# jeans = [
#     "Diana", "Harper", "Juliette", "Sienna", "Isabel",
#     "Audrey", "Celeste", "Phoebe", "Emilia", "Florence",
#     "Margo", "Eleanor", "Claudia", "Colette", "Bianca",
#     "Anastasia", "Lena", "Amelie", "Louisa", "Monica",
#     "Rosa", "Thea", "Verity", "Naomi", "Tessa",
#     "Beatrix", "Delilah", "Eliza", "Helena", "Sylvia",
#     "Odette", "Simone", "Freya", "Camilla", "Vera",
#     "Gwen", "Margaux", "Adeline", "Clara", "Anneliese",
#     "Bridget", "Catherine", "Daphne", "Elinor", "Felicity",
#     "Georgina", "Hannah", "Isolde", "Jade", "Maribel"
# ]

# %% [markdown]
# ## Doen Product Names

# %%
# # Doen Dresses
# url = 'https://www.shopdoen.com/collections/dresses?utm_source=google&campaign_id=10806218531&ad_id=724988960813&utm_medium=cpc&utm_campaign=actual_campaign_name_hardcoded&utm_content=104400744937&utm_term=&gclid=Cj0KCQiA4L67BhDUARIsADWrl7E0ZY9XqbDkatpsUlP50aYS24KA_m3tyCe0SNkiYI4icGTUFzKFJ7YaAoDHEALw_wcB&gad_source=1'
# response = requests.get(url)

# # response.status_code
# html = response.text
# soup = BeautifulSoup(html, "html.parser") 

# elements = soup.select(".full-unstyled-link") # Size

# for element in elements:
#     print(element.text.strip())

# %%
# # Doen Tops
# url = 'https://www.shopdoen.com/collections/tops'
# response = requests.get(url)

# # response.status_code
# html = response.text
# soup = BeautifulSoup(html, "html.parser") 

# elements = soup.select(".full-unstyled-link") # Size

# for element in elements:
#     print(element.text.strip())
