# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from datetime import datetime as dt
# import datetime as dt
from scheduler import Scheduler
import scheduler.trigger as trigger

# %% [markdown]
# # Doen Dresses

# %% [markdown]
# ## Extract

# %%
# Sold Doen Dresses
url = 'https://poshmark.com/search?query=Doen&brand%5B%5D=Doen&availability=sold_out&department=Women&category=Dresses'

response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Set dress styles

# %%
# Dresses
dresses = [
    "Ischia", "Marianne", "Rosaria", "Lisbeth", "Wilmina",
    "Aurora", "Delphine", "Clara", "Sabine", "Odette",
    "Evelyn", "Juliette", "Amelie", "Camille", "Vera",
    "Fiona", "Nina", "Corinne", "Helene", "Lucille",
    "Margot", "Anya", "Freya", "Sylvie", "Celine",
    "Daphne", "Iris", "Luna", "Flora", "Amara",
    "Maeve", "Adelaide", "Ophelia", "Scarlett", "Viola",
    "Anastasia", "Claudia", "Elise", "Matilda", "Eloise",
    "Gwendolyn", "Ivy", "Cecilia", "Esme", "Tessa",
    "Madeleine", "Poppy", "Adele", "Serena", "Genevieve",
    "Lorraine", "Merla", "Narcisse", "Augustina", "Sabrina",
    "Alessandra", "Leyah", "Guinevere", "Francetta", "Kaira",
    "Raquella", "Pamelina", "Quinn", "Celestine", "Emmaretta",
    "Piper", "Violetta", "Noisette", "Franique", "Sera",
    "Lovisa", "Rhodia", "Gladys"
]


dresses = [x.lower() for x in dresses]
dresses = [x +' ' for x in dresses] # add a space after the name to exlude partial matches

# %% [markdown]
# ### Create Dataframe

# %%
titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    for dress in dresses:
        if dress in title:
            style = dress
            break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"dress",
                 'style':style}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_6472/3327822001.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)

# %%
df.head()
# Out:
#                                                title  price size category  \
# 0  ⚡️cco sale⚡️ doen malta floral belted corduroy...   75.0    M    dress
# 1  doen victorie maxi dress in mirbeau garden flo...  200.0    M    dress
# 2   doen celestine red velvet heirloom dress nwt new  489.0    S    dress
# 3  doen preston liberty floral midi maxi tie wast...  200.0    M    dress
# 4              doen emmaretta floral midi maxi dress  195.0    M    dress
#
#         style
# 0        None
# 1        None
# 2  celestine
# 3        None
# 4  emmaretta

# %% [markdown]
# ## Load

# %%
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/doen_dresses_{file_timestamp}.csv',index=False)

# Log process
message = "Doen Dresses Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

# %% [markdown]
# # Doen Tops

# %% [markdown]
# ## Extract

# %%
# Sold Doen Tops
url = 'https://poshmark.com/brand/Doen-Women-Tops?availability=sold_out'
response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Set Styles

# %%
# Tops
tops = [
    "Henri", "Anisa", "Emiliana", "Ingrid", "Joelle",
    "Celeste", "Faye", "Gabrielle", "Juliana", "Odessa",
    "Viola", "Monique", "Sophie", "Claudine", "Elena",
    "Leona", "Paloma", "Bianca", "Marisol", "Estelle",
    "Inez", "Lorena", "Delilah", "Jocelyn", "Amara",
    "Colette", "Marielle", "Florelle", "Adeline", "Renee",
    "Sabrina", "Fleur", "Noemi", "Simone", "Vera",
    "Natalia", "Yvette", "Clarisse", "Odile", "Beatrice",
    "Camilla", "Tatiana", "Nadia", "Cleo", "Lydia",
    "Josephine", "Evelina", "Lucia", "Freya", "Marion",
    "Scarlet", "Jane", "June", "Lille", "Fidella", "Frederica",
    "Anaya", "Idella", "Baptisia", "Eldoris", "Camri",
    "Jacey", "Leia", "Amaline", "Solange", "Evette",
    "Lois", "Alida", "Ashby", "Nerida", "Agotha",
    "Frances", "Paola", "Vivienne"
]

tops = [x.lower() for x in tops]
tops = [x +' ' for x in tops] # add a space after the name to exlude partial matches

# %% [markdown]
# ### Create Dataframe

# %%
titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    for top in tops:
        if top in title:
            style = top
            break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"top",
                 'style':style}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_6472/746729972.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)

# %%
df
# Out:
#                                                 title  price size category  \
# 0     doen fidella sleeveless blouse salt top new nwt  118.0    M      top
# 1                          doen lois tank top new nwt   95.0    M      top
# 2                     doen seine rosebud tank new nwt   95.0    L      top
# 3                                     doen agotha top  130.0   XS      top
# 4                            doen vera top in salt xs  125.0   XS      top
# 5   doen viola black and white floral ruffled top ...   90.0    L      top
# 6                dôen lille top in monte isola stripe  100.0   XS      top
# 7                                     the jane blouse   80.0    S      top
# 8        dôen alida top, countryside\npatchwork print   95.0    S      top
# 9              doen sparrow top cream seafarer stripe   85.0    S      top
# 10    doen ashby cotton pointelle turtleneck black/ m  120.0    M      top
# 11                 new doen nerida top in ivory small  116.0    S      top
# 12          doen frederica top in alice blue size xxs  140.0  XXS      top
# 13                          doen pirouette top medium   95.0    M      top
# 14  dôen minou pointelle turtleneck silk alpaca do...  100.0    M      top
# 15  nwt doen docia henri taylor eyelet lace puff s...   92.0   XS      top
# 16                  dòen flowered blouse of good size   90.0    L      top
# 17                                        doen blouse   67.0    M      top
# 18            doen ariste top in golden mesa flor, xs  110.0   XS      top
# 19  doen alida countryside patchwork puff sleeve c...  180.0   XS      top
# 20          doen pointelle organic cotton mock neck m  100.0    M      top
# 21                                   doen frances top   87.0    M      top
# 22          doen rose blouse in sissinghurst floral 🌸   90.0    M      top
# 23  doen simone top in mother of pearl, brand new ...  250.0   XS      top
# 24            doen paola tee striped red size small s   75.0    S      top
# 25            doen black albertine blouse top size xl  130.0   XL      top
# 26  new with tags doen tonya top in dahlia ikat si...   50.0    L      top
# 27                   dôen june top in moss size small   60.0    S      top
# 28  dôen jane blouse in traveler block print off-w...  150.0   XS      top
# 29  dôen jane blouse in tierra cotton viscose size...  148.0   XS      top
# 30  dôen jane blouse in sky somerset plaid organic...  158.0  XXS      top
# 31  dôen jane blouse in rossendale valley plaid re...  148.0   XS      top
# 32  dôen jane blouse pink sunflower block print or...  125.0   XS      top
# 33  dôen jane blouse in navy somerset plaid organi...  158.0  XXS      top
# 34  dôen jane blouse in navy bisou floral organic ...  155.0   XS      top
# 35  dôen jane blouse in moss organic cotton viscos...  148.0   XS      top
# 36  dôen jane blouse in midnight st. germain plaid...  148.0   XS      top
# 37  dôen jane blouse in la maddalena gingham organ...  149.0   XS      top
# 38  dôen jane blouse in indigo stripe blue pattern...  158.0   XS      top
# 39  dôen jane blouse in dusty teal cotton viscose ...  148.0   XS      top
# 40  dôen jane blouse dusty teal cotton viscose siz...  141.0   XS      top
# 41  dôen jane blouse in desert blooms block print ...  149.0    S      top
# 42  dôen jane blouse in desert blooms block print ...  149.0   XS      top
# 43  dôen jane blouse in berry bisou floral organic...  158.0   XS      top
# 44  dôen jane blouse in azure french plaid organic...  159.0  XXS      top
# 45  doen scarlet top in golden hour paisley size s...   64.0    S      top
# 46  doen | the jane blouse- blue primrose floral |...  190.0    M      top
# 47     doen vivienne tee long sleeve pointelle salt m   80.0    M      top
#
#          style
# 0     fidella
# 1        lois
# 2         None
# 3      agotha
# 4        vera
# 5       viola
# 6       lille
# 7        jane
# 8       alida
# 9         None
# 10      ashby
# 11     nerida
# 12  frederica
# 13        None
# 14        None
# 15      henri
# 16        None
# 17        None
# 18        None
# 19      alida
# 20        None
# 21    frances
# 22        None
# 23     simone
# 24      paola
# 25        None
# 26        None
# 27       june
# 28       jane
# 29       jane
# 30       jane
# 31       jane
# 32       jane
# 33       jane
# 34       jane
# 35       jane
# 36       jane
# 37       jane
# 38       jane
# 39       jane
# 40       jane
# 41       jane
# 42       jane
# 43       jane
# 44       jane
# 45    scarlet
# 46       jane
# 47   vivienne

# %% [markdown]
# ## Load

# %%
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/doen_tops_{file_timestamp}.csv',index=False)

# Log process
message = "Doen Tops Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

# %% [markdown]
# # Doen Skirts

# %% [markdown]
# ## Extract

# %%
# Sold Doen Skirts
url = 'https://poshmark.com/brand/Doen-Women-Skirts?availability=sold_out'
response = requests.get(url)
# response.status_code
html = response.text
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Set Styles

# %%
# Skirts
skirts = [
    "Elowen", "Sebastiane", "Raina", "Beatrice", "Florence",
    "Odile", "Esther", "Giselle", "Clementine", "Simone",
    "Aurora", "Emmeline", "Coralie", "Juliet", "Isadora",
    "Felicity", "Lucia", "Vivienne", "Celestine", "Anais",
    "Noelle", "Gabriella", "Liliana", "Violette", "Rosalind",
    "Allegra", "Seraphina", "Eleanor", "Arden", "Madeleine",
    "Sophia", "Helena", "Marguerite", "Arabelle", "Isla",
    "Delphine", "Anouk", "Carys", "Evangeline", "Maris",
    "Odessa", "Viola", "Lenore", "Selene", "Camille",
    "Amelie", "Liora", "Fiona", "Adria", "Melisande","Elowena",
    "Nandi","Cheri","Fabienne","Rieti","Sanremo"
]

skirts = [x.lower() for x in skirts]
# skirts = [x +' ' for x in skirts] # add a space after the name to exlude partial matches

# %% [markdown]
# ### Create Dataframe

# %%
titles = soup.select(".tile__title") # listing title
prices = soup.select(".fw--bold") # sold price
sizes = soup.select(".ellipses.tile__details__pipe__size") # Size

attribs = ['title','price','size','category','style']
df = pd.DataFrame(columns = attribs)


for x in range(len(titles)):
    title = str.lower(titles[x].text.strip())
    price = float(prices[x].text.strip()[1:])
    size = sizes[x].text.strip()[6:]
    
    style = None
    for skirt in skirts:
        if skirt in title:
            style = skirt
            break # stop after the first match 
    
    data_dict = {'title':title,
                 'price':price,
                 'size':size,
                 'category':"skirt",
                 'style':style}
    
    df1 = pd.DataFrame(data_dict,index=[0])
    df = pd.concat([df,df1], axis =0,ignore_index= True)
# Out:
# /var/folders/8p/wjrnxtq910g62m0r4449h6zr0000gn/T/ipykernel_6472/1613183247.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df1], axis =0,ignore_index= True)

# %%
df
# Out:
#                                                 title  price     size  \
# 0   doen elowena skirt in villette paisley, brand ...  170.0        S
# 1   doen sebastiane lace skirt in black, brand new...  180.0        S
# 2                 doen nandi skirt in daffodil yellow  168.0  Various
# 3   doen sebastiane lace skirt in black, brand new...  180.0       XS
# 4             nwt doen elowen skirt in deep navy sz m  220.0        M
# 5                            doen elowen, small, vguc  200.0        S
# 6                     doen sebastiane skirt in powder  160.0        S
# 7                 doen cheri skirt, size 6, deep navy  140.0        6
# 8                          doen skirt , black, size 8  178.0        8
# 9   fabienne skirt\nin navy countryside plaid\nsize m  250.0        M
# 10  doen elowen 100% silk skirt in rose hillside h...  200.0        M
# 11  doen buttercup dress in black winter ditsy pri...  127.0        S
# 12                   nwt gap × dôen eyelet midi skirt   75.0        L
# 13                                         doen skirt  150.0        S
# 14                nwt dôen sebastiane skirt in powder  163.0        M
# 15                    nwot doen sebastiane lace skirt  185.0        M
# 16                        doen rieti skirt - s - salt  180.0        S
# 17                           sebastiane skirt in salt  149.0        S
# 18        doen printed midi length wrap skirt size xl  125.0       XL
# 19              doen sebastiane skirt - white - large  110.0        L
# 20                    doen elowen skirt and amora top  325.0        S
# 21                                    doen silk skirt   97.0        L
# 22                                  doen amalfi skirt  175.0        M
# 23                             doen sanremo skirt nwt  120.0        S
# 24                             doen midi floral skirt   65.0       XS
# 25  doen sz xs sebastiane skirt midi scalloped ivo...  140.0       XS
# 26                                  doen elowen skirt  185.0       XS
# 27               dôenelowen silk lace-trim skirt blue  180.0       XS
# 28   dôen sebastiane skirt in la maddalena gingham xl  175.0       XL
# 29  doen julep wrap handkerchief hem skirt in blac...  140.0        S
# 30  doen sabina embroidered a-line full skirt, whi...   55.0      XXL
# 31                nwt dôen sebastiane skirt in powder  150.0        M
# 32  dôen elowen silk midi skirt in rose hillside f...  150.0        S
# 33                                   sebastiane skirt  200.0        M
# 34                    doen elowen skirt in dusty blue  227.0        M
# 35                  doen sebastiane skirt black small  148.0        S
# 36                     nwt dôen sanremo skirt size xl   50.0       XL
# 37                            paris style white skirt   84.0       XS
# 38                                         pink skirt   60.0       XS
# 39     doen elowen silk skirt bleu wildflower thicket  200.0        M
# 40                           doen elowen, pink, small  160.0        S
# 41           doen elowena skirt in camille dot, small  250.0        S
# 42                     doen sebastiane skirt sz small  185.0        S
# 43      doen sebastian skirt in powder white sz large  225.0        L
# 44                        doen georgina skirt in salt  110.0        S
# 45                              doen sebastiane skirt  150.0        S
# 46         doen elowen skirt in cornwall plaid size s  265.0        S
# 47                              dôen x gap midi skirt   20.0        S
#
#    category       style
# 0     skirt      elowen
# 1     skirt  sebastiane
# 2     skirt       nandi
# 3     skirt  sebastiane
# 4     skirt      elowen
# 5     skirt      elowen
# 6     skirt  sebastiane
# 7     skirt       cheri
# 8     skirt        None
# 9     skirt    fabienne
# 10    skirt      elowen
# 11    skirt        None
# 12    skirt        None
# 13    skirt        None
# 14    skirt  sebastiane
# 15    skirt  sebastiane
# 16    skirt       rieti
# 17    skirt  sebastiane
# 18    skirt        None
# 19    skirt  sebastiane
# 20    skirt      elowen
# 21    skirt        None
# 22    skirt        None
# 23    skirt     sanremo
# 24    skirt        None
# 25    skirt  sebastiane
# 26    skirt      elowen
# 27    skirt      elowen
# 28    skirt  sebastiane
# 29    skirt        None
# 30    skirt        None
# 31    skirt  sebastiane
# 32    skirt      elowen
# 33    skirt  sebastiane
# 34    skirt      elowen
# 35    skirt  sebastiane
# 36    skirt     sanremo
# 37    skirt        None
# 38    skirt        None
# 39    skirt      elowen
# 40    skirt      elowen
# 41    skirt      elowen
# 42    skirt  sebastiane
# 43    skirt        None
# 44    skirt        None
# 45    skirt  sebastiane
# 46    skirt      elowen
# 47    skirt        None

# %% [markdown]
# ## Load

# %%
# Write to CSV
timestamp_format = '%Y-%h-%d-%H:%M:%S'
now = dt.now()
timestamp = now.strftime(timestamp_format)
df['ingest_timestamp'] = timestamp

file_timestamp_format = '%Y%m%d_%H-%M-%S'
file_timestamp = now.strftime(file_timestamp_format)

df.to_csv(f'data/doen_skirts_{file_timestamp}.csv',index=False)

# Log process
message = "Doen Skirts Logged"
with open("scrape_log.txt","a") as file:
    file.write(timestamp + " " + message + '\n')

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Product Style Names

# %%
# # Tops
# tops = [
#     "Henri", "Anisa", "Emiliana", "Ingrid", "Joelle",
#     "Celeste", "Faye", "Gabrielle", "Juliana", "Odessa",
#     "Viola", "Monique", "Sophie", "Claudine", "Elena",
#     "Leona", "Paloma", "Bianca", "Marisol", "Estelle",
#     "Inez", "Lorena", "Delilah", "Jocelyn", "Amara",
#     "Colette", "Marielle", "Florelle", "Adeline", "Renee",
#     "Sabrina", "Fleur", "Noemi", "Simone", "Vera",
#     "Natalia", "Yvette", "Clarisse", "Odile", "Beatrice",
#     "Camilla", "Tatiana", "Nadia", "Cleo", "Lydia",
#     "Josephine", "Evelina", "Lucia", "Freya", "Marion"
# ]

# # Skirts
# skirts = [
#     "Elowen", "Sebastiane", "Raina", "Beatrice", "Florence",
#     "Odile", "Esther", "Giselle", "Clementine", "Simone",
#     "Aurora", "Emmeline", "Coralie", "Juliet", "Isadora",
#     "Felicity", "Lucia", "Vivienne", "Celestine", "Anais",
#     "Noelle", "Gabriella", "Liliana", "Violette", "Rosalind",
#     "Allegra", "Seraphina", "Eleanor", "Arden", "Madeleine",
#     "Sophia", "Helena", "Marguerite", "Arabelle", "Isla",
#     "Delphine", "Anouk", "Carys", "Evangeline", "Maris",
#     "Odessa", "Viola", "Lenore", "Selene", "Camille",
#     "Amelie", "Liora", "Fiona", "Adria", "Melisande"
# ]

# # Pants
# pants = [
#     "Diana", "Clara", "Eloise", "Harper", "Amalia",
#     "Marguerite", "Florine", "Estelle", "Genevieve", "Sabine",
#     "Odessa", "Lorelei", "Miriam", "Joanna", "Lenore",
#     "Viviana", "Cecile", "Delia", "Lucinda", "Aurora",
#     "Francesca", "Eliana", "Isobel", "Norah", "Camille",
#     "Selena", "Veronica", "Marina", "Adela", "Corinne",
#     "Penelope", "Rosalyn", "Evelyn", "Jocasta", "Beatrice",
#     "Cressida", "Natalia", "Florence", "Sophia", "Lyra",
#     "Octavia", "Philippa", "Sabina", "Clarissa", "Giselle",
#     "Ines", "Amara", "Elara", "Lucille", "Mattea"
# ]

# # Jeans
# jeans = [
#     "Diana", "Harper", "Juliette", "Sienna", "Isabel",
#     "Audrey", "Celeste", "Phoebe", "Emilia", "Florence",
#     "Margo", "Eleanor", "Claudia", "Colette", "Bianca",
#     "Anastasia", "Lena", "Amelie", "Louisa", "Monica",
#     "Rosa", "Thea", "Verity", "Naomi", "Tessa",
#     "Beatrix", "Delilah", "Eliza", "Helena", "Sylvia",
#     "Odette", "Simone", "Freya", "Camilla", "Vera",
#     "Gwen", "Margaux", "Adeline", "Clara", "Anneliese",
#     "Bridget", "Catherine", "Daphne", "Elinor", "Felicity",
#     "Georgina", "Hannah", "Isolde", "Jade", "Maribel"
# ]

# %% [markdown]
# ## Doen Product Names

# %%
# # Doen Dresses
# url = 'https://www.shopdoen.com/collections/dresses?utm_source=google&campaign_id=10806218531&ad_id=724988960813&utm_medium=cpc&utm_campaign=actual_campaign_name_hardcoded&utm_content=104400744937&utm_term=&gclid=Cj0KCQiA4L67BhDUARIsADWrl7E0ZY9XqbDkatpsUlP50aYS24KA_m3tyCe0SNkiYI4icGTUFzKFJ7YaAoDHEALw_wcB&gad_source=1'
# response = requests.get(url)

# # response.status_code
# html = response.text
# soup = BeautifulSoup(html, "html.parser") 

# elements = soup.select(".full-unstyled-link") # Size

# for element in elements:
#     print(element.text.strip())

# %%
# # Doen Tops
# url = 'https://www.shopdoen.com/collections/tops'
# response = requests.get(url)

# # response.status_code
# html = response.text
# soup = BeautifulSoup(html, "html.parser") 

# elements = soup.select(".full-unstyled-link") # Size

# for element in elements:
#     print(element.text.strip())
