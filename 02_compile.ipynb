# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
import glob

# %% [markdown]
# # Compile

# %%
file_path = "data/*.csv"
file_list = glob.glob(file_path)
file_list
# Out:
# ['data/doen_dresses_20241228_23-19-21.csv',
#  'data/doen_skirts_20241229_11-30-36.csv',
#  'data/doen_tops_20241229_11-30-35.csv',
#  'data/doen_skirts_20241228_23-19-23.csv',
#  'data/doen_tops_20241228_23-19-22.csv',
#  'data/doen_dresses_20241229_11-30-33.csv']

# %%
df = pd.DataFrame()

for file in file_list:
    df1 = pd.read_csv(file)
    df = pd.concat([df,df1], ignore_index = True)
    
df
# Out:
#                                                  title  price size category  \
# 0    ⚡️cco sale⚡️ doen malta floral belted corduroy...   75.0    M    dress
# 1    doen victorie maxi dress in mirbeau garden flo...  200.0    M    dress
# 2     doen celestine red velvet heirloom dress nwt new  489.0    S    dress
# 3    doen preston liberty floral midi maxi tie wast...  200.0    M    dress
# 4                doen emmaretta floral midi maxi dress  195.0    M    dress
# ..                                                 ...    ...  ...      ...
# 283  doen charleston dress in neutre jardin de papi...   90.0  XXS    dress
# 284  dôen like new rare monceau dress in blue liber...  150.0    M    dress
# 285  doen market wrap 100% silk dress, s, great con...   75.0    S    dress
# 286                                doen noisette dress   76.0    S    dress
# 287  doen gwendolyn silk lily of the valley maxi dr...  300.0    L    dress
#
#           style      ingest_timestamp
# 0           NaN  2024-Dec-28-23:19:21
# 1           NaN  2024-Dec-28-23:19:21
# 2    celestine   2024-Dec-28-23:19:21
# 3           NaN  2024-Dec-28-23:19:21
# 4    emmaretta   2024-Dec-28-23:19:21
# ..          ...                   ...
# 283         NaN  2024-Dec-29-11:30:33
# 284         NaN  2024-Dec-29-11:30:33
# 285         NaN  2024-Dec-29-11:30:33
# 286   noisette   2024-Dec-29-11:30:33
# 287  gwendolyn   2024-Dec-29-11:30:33
#
# [288 rows x 6 columns]

# %% [markdown]
# # Remove Duplicates

# %%
[df.columns]
# Out:
# [Index(['title', 'price', 'size', 'category', 'style', 'ingest_timestamp'], dtype='object')]

# %%
df = df.sort_values(by = ['title', 'price', 'size', 'category', 'style','ingest_timestamp'],
                    ascending = [True,True,True,True,True,False])

df = df.drop_duplicates(subset = ['title', 'price', 'size', 'category', 'style'], keep = 'first')

# %%
df
# Out:
#                                                  title  price size category  \
# 259          brown floral doên marfa dress, size small   75.0    S    dress
# 265     copy - doen emmaretta floral cotton midi-dress  115.0   XS    dress
# 277                                   doen adele dress  100.0    4    dress
# 102                                    doen agotha top  130.0   XS      top
# 115  doen alida countryside patchwork puff sleeve c...  180.0   XS      top
# ..                                                 ...    ...  ...      ...
# 81                                    sebastiane skirt  200.0    M    skirt
# 65                            sebastiane skirt in salt  149.0    S    skirt
# 104                                    the jane blouse   80.0    S      top
# 247  ⚡️cco sale⚡️ doen malta floral belted corduroy...   75.0    M    dress
# 46   🎀 euc! dôen lovisa 🎀 nightgown- sweet daisy pr...  172.0   XS    dress
#
#           style      ingest_timestamp
# 259         NaN  2024-Dec-29-11:30:33
# 265  emmaretta   2024-Dec-29-11:30:33
# 277      adele   2024-Dec-29-11:30:33
# 102     agotha   2024-Dec-29-11:30:35
# 115      alida   2024-Dec-29-11:30:35
# ..          ...                   ...
# 81   sebastiane  2024-Dec-29-11:30:36
# 65   sebastiane  2024-Dec-29-11:30:36
# 104       jane   2024-Dec-29-11:30:35
# 247         NaN  2024-Dec-29-11:30:33
# 46      lovisa   2024-Dec-28-23:19:21
#
# [150 rows x 6 columns]
